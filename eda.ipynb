# %%
import pandas as pd

train_labels = pd.read_csv("/kaggle/input/competitions/amex-default-prediction/train_labels.csv")
train_labels.shape
# Out:
# (458913, 2)

# %%
df = pd.read_csv("/kaggle/input/competitions/amex-default-prediction/train_data.csv", nrows=1)
columns = df.columns.tolist()[1:]

# %%
train_labels["target"].value_counts(normalize=True)
# Out:
# target
# 0    0.741066
# 1    0.258934
# Name: proportion, dtype: float64

# %%
train_data_iterator = pd.read_csv("/kaggle/input/competitions/amex-default-prediction/train_data.csv", chunksize=1)

# %%
import gc
from tqdm.auto import tqdm
for chunk in tqdm(train_data_iterator):
    del chunk
    gc.collect()
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_445/2162671503.py in <cell line: 0>()
#       3 for chunk in tqdm(train_data_iterator):
#       4     del chunk
# ----> 5     gc.collect()
#
# KeyboardInterrupt:

# %%
row_count = 0
for index, chunk in enumerate(train_data_iterator):
    print(index, chunk.shape)
    row_count += chunk.shape[0]
# Out:
# 0 (10000, 190)
# 1 (10000, 190)
# 2 (10000, 190)
# 3 (10000, 190)
# 4 (10000, 190)
# 5 (10000, 190)
# 6 (10000, 190)
# 7 (10000, 190)
# 8 (10000, 190)
# 9 (10000, 190)
# 10 (10000, 190)
# 11 (10000, 190)
# 12 (10000, 190)
# 13 (10000, 190)
# 14 (10000, 190)
# 15 (10000, 190)
# 16 (10000, 190)
# 17 (10000, 190)
# 18 (10000, 190)
# 19 (10000, 190)
# 20 (10000, 190)
# 21 (10000, 190)
# 22 (10000, 190)
# 23 (10000, 190)
# 24 (10000, 190)
# 25 (10000, 190)
# 26 (10000, 190)
# 27 (10000, 190)
# 28 (10000, 190)
# 29 (10000, 190)
# 30 (10000, 190)
# 31 (10000, 190)
# 32 (10000, 190)
# 33 (10000, 190)
# 34 (10000, 190)
# 35 (10000, 190)
# 36 (10000, 190)
# 37 (10000, 190)
# 38 (10000, 190)
# 39 (10000, 190)
# 40 (10000, 190)
# 41 (10000, 190)
# 42 (10000, 190)
# 43 (10000, 190)
# 44 (10000, 190)
# 45 (10000, 190)
# 46 (10000, 190)
# 47 (10000, 190)
# 48 (10000, 190)
# 49 (10000, 190)
# 50 (10000, 190)
# 51 (10000, 190)
# 52 (10000, 190)
# 53 (10000, 190)
# 54 (10000, 190)
# 55 (10000, 190)
# 56 (10000, 190)
# 57 (10000, 190)
# 58 (10000, 190)
# 59 (10000, 190)
# 60 (10000, 190)
# 61 (10000, 190)
# 62 (10000, 190)
# 63 (10000, 190)
# 64 (10000, 190)
# 65 (10000, 190)
# 66 (10000, 190)
# 67 (10000, 190)
# 68 (10000, 190)
# 69 (10000, 190)
# 70 (10000, 190)
# 71 (10000, 190)
# 72 (10000, 190)
# 73 (10000, 190)
# 74 (10000, 190)
# 75 (10000, 190)
# 76 (10000, 190)
# 77 (10000, 190)
# 78 (10000, 190)
# 79 (10000, 190)
# 80 (10000, 190)
# 81 (10000, 190)
# 82 (10000, 190)
# 83 (10000, 190)
# 84 (10000, 190)
# 85 (10000, 190)
# 86 (10000, 190)
# 87 (10000, 190)
# 88 (10000, 190)
# 89 (10000, 190)
# 90 (10000, 190)
# 91 (10000, 190)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_355/1592637518.py in <cell line: 0>()
#       1 row_count = 0
# ----> 2 for index, chunk in enumerate(train_data_iterator):
#       3     print(index, chunk.shape)
#       4     row_count += chunk.shape[0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __next__(self)
#    1841     def __next__(self) -> DataFrame:
#    1842         try:
# -> 1843             return self.get_chunk()
#    1844         except StopIteration:
#    1845             self.close()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1983                 raise StopIteration
#    1984             size = min(size, self.nrows - self._currow)
# -> 1985         return self.read(nrows=size)
#    1986
#    1987     def __enter__(self) -> Self:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._maybe_upcast()
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/multiarray.py in putmask(a, mask, values)
#    1138
#    1139
# -> 1140 @array_function_from_c_func_and_dispatcher(_multiarray_umath.putmask)
#    1141 def putmask(a, /, mask, values):
#    1142     """
#
# KeyboardInterrupt:

# %%
61 * 10_000
# Out:
# 610000

# %%
train_labels.shape
# Out:
# (458913, 2)
