# %%
import pandas as pd

train_labels = pd.read_csv("/kaggle/input/competitions/amex-default-prediction/train_labels.csv")
train_labels.shape
# Out:
# (458913, 2)

# %%
train_labels["target"].value_counts(normalize=True)
# Out:
# target
# 0    0.741066
# 1    0.258934
# Name: proportion, dtype: float64

# %%
import polars as pl

df = pl.read_csv("/kaggle/input/competitions/amex-default-prediction/train_data.csv")

# %%
df.with_columns(pl.col("P_2").cast(pl.Float32))
# Out:
# shape: (5_531_451, 190)
# ┌──────────────────┬────────────┬──────────┬──────────┬───┬───────┬──────────┬──────────┬──────────┐
# │ customer_ID      ┆ S_2        ┆ P_2      ┆ D_39     ┆ … ┆ D_142 ┆ D_143    ┆ D_144    ┆ D_145    │
# │ ---              ┆ ---        ┆ ---      ┆ ---      ┆   ┆ ---   ┆ ---      ┆ ---      ┆ ---      │
# │ str              ┆ str        ┆ f32      ┆ f64      ┆   ┆ str   ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════════════╪════════════╪══════════╪══════════╪═══╪═══════╪══════════╪══════════╪══════════╡
# │ 0000099d6bd59705 ┆ 2017-03-09 ┆ 0.938469 ┆ 0.001733 ┆ … ┆ null  ┆ 0.000569 ┆ 0.00061  ┆ 0.002674 │
# │ 2cdcda90ffabf5…  ┆            ┆          ┆          ┆   ┆       ┆          ┆          ┆          │
# │ 0000099d6bd59705 ┆ 2017-04-07 ┆ 0.936665 ┆ 0.005775 ┆ … ┆ null  ┆ 0.009576 ┆ 0.005492 ┆ 0.009217 │
# │ 2cdcda90ffabf5…  ┆            ┆          ┆          ┆   ┆       ┆          ┆          ┆          │
# ...

# %%
c = 0
for col in df.columns:
    if pl.datatypes.Float64 == df[col].dtype:
        df[col] =
# Out:
# 164

# %%
df.dtype
# Out:
# Float64

# %%
pl.datatypes.Float64 == df["P_2"].dtype
# Out:
# True

# %%
import numpy as np
np.float64 == df["P_2"].dtype
# Out:
# False

# %%
row_count = 0
for index, chunk in enumerate(train_data_iterator):
    print(index, chunk.shape)
    row_count += chunk.shape[0]
# Out:
# 0 (10000, 190)
# 1 (10000, 190)
# 2 (10000, 190)
# 3 (10000, 190)
# 4 (10000, 190)
# 5 (10000, 190)
# 6 (10000, 190)
# 7 (10000, 190)
# 8 (10000, 190)
# 9 (10000, 190)
# 10 (10000, 190)
# 11 (10000, 190)
# 12 (10000, 190)
# 13 (10000, 190)
# 14 (10000, 190)
# 15 (10000, 190)
# 16 (10000, 190)
# 17 (10000, 190)
# 18 (10000, 190)
# 19 (10000, 190)
# 20 (10000, 190)
# 21 (10000, 190)
# 22 (10000, 190)
# 23 (10000, 190)
# 24 (10000, 190)
# 25 (10000, 190)
# 26 (10000, 190)
# 27 (10000, 190)
# 28 (10000, 190)
# 29 (10000, 190)
# 30 (10000, 190)
# 31 (10000, 190)
# 32 (10000, 190)
# 33 (10000, 190)
# 34 (10000, 190)
# 35 (10000, 190)
# 36 (10000, 190)
# 37 (10000, 190)
# 38 (10000, 190)
# 39 (10000, 190)
# 40 (10000, 190)
# 41 (10000, 190)
# 42 (10000, 190)
# 43 (10000, 190)
# 44 (10000, 190)
# 45 (10000, 190)
# 46 (10000, 190)
# 47 (10000, 190)
# 48 (10000, 190)
# 49 (10000, 190)
# 50 (10000, 190)
# 51 (10000, 190)
# 52 (10000, 190)
# 53 (10000, 190)
# 54 (10000, 190)
# 55 (10000, 190)
# ...

# %%
61 * 10_000
# Out:
# 610000

# %%
train_labels.shape
# Out:
# (458913, 2)
